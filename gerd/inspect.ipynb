# %%
import torch
import matplotlib.pyplot as plt

# %%
# !ls /mnt/disk2/0.8-1000/
# Out:
# 0.dat	  1225.dat  1450.dat  1676.dat	1900.dat  325.dat  550.dat  776.dat
# 1000.dat  1226.dat  1451.dat  1677.dat	1901.dat  326.dat  551.dat  777.dat
# 1001.dat  1227.dat  1452.dat  1678.dat	1902.dat  327.dat  552.dat  778.dat
# 1002.dat  1228.dat  1453.dat  1679.dat	1903.dat  328.dat  553.dat  779.dat
# 1003.dat  1229.dat  1454.dat  167.dat	1904.dat  329.dat  554.dat  77.dat
# 1004.dat  122.dat   1455.dat  1680.dat	1905.dat  32.dat   555.dat  780.dat
# 1005.dat  1230.dat  1456.dat  1681.dat	1906.dat  330.dat  556.dat  781.dat
# 1006.dat  1231.dat  1457.dat  1682.dat	1907.dat  331.dat  557.dat  782.dat
# 1007.dat  1232.dat  1458.dat  1683.dat	1908.dat  332.dat  558.dat  783.dat
# 1008.dat  1233.dat  1459.dat  1684.dat	1909.dat  333.dat  559.dat  784.dat
# 1009.dat  1234.dat  145.dat   1685.dat	190.dat   334.dat  55.dat   785.dat
# 100.dat   1235.dat  1460.dat  1686.dat	1910.dat  335.dat  560.dat  786.dat
# 1010.dat  1236.dat  1461.dat  1687.dat	1911.dat  336.dat  561.dat  787.dat
# ...

# %%
n = 103
d = torch.load(f"/mnt/disk2/0.8-1100/{n}.dat", map_location="cuda:1")
plt.imshow(d[0].to_dense()[100].squeeze().cpu())
plt.colorbar()
